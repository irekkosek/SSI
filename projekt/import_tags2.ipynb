# %%
import pandas as pd
tags = pd.read_csv(r"tags.csv")
df = pd.read_csv(r"dishes.csv")
df_true_false = df.copy()
# tags = tags[:30]
df = df[:80]

# %%
df.head()
# Out:
#    index_tasty   id_                        name                      slug
# 0            0   868     Homemade Cinnamon Rolls   homemade-cinnamon-rolls  \
# 1            1  6124              Whipped Coffee            whipped-coffee
# 2            2  3094             Fluffy Pancakes   fluffy-perfect-pancakes
# 3            3  4693  How to Make Cinnamon Rolls  tasty-101-cinnamon-rolls
# 4            4  1655     Healthy Banana Pancakes   healthy-banana-pancakes
#
#                                            video_url
# 0  https://vid.tasty.co/output/25812/mp4_640x640/...  \
# 1  https://vid.tasty.co/output/163616/landscape_4...
# 2  https://vid.tasty.co/output/65088/landscape_48...
# 3  https://vid.tasty.co/output/121022/landscape_4...
# 4  https://vid.tasty.co/output/27116/mp4_640x640/...
#
#                                        thumbnail_url
# 0  https://img.buzzfeed.com/video-api-prod/assets...  \
# 1  https://img.buzzfeed.com/video-api-prod/assets...
# ...

# %%
for index in tags.index:
    tag_id = tags.at[index,"id"]
    tag_name = tags.at[index,"name"]
    tag_type = tags.at[index,"type"]
    for df_index in df.index:
        df.loc[df_index,f"{tag_type}_{tag_name}"] = df_tags_series.str.contains(str(tag_id)).astype(int)
        df_true_false.loc[f"{tag_type}_{tag_name}"] = df["tags"].str.contains(str(tag_id))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 6
#       4 tag_type = tags.at[index,"type"]
#       5 for df_index in df.index:
# ----> 6     df_tags_series = pd.Series(df.loc[df_index,"tags"],dtype=str, sep=",")
#       7     df.loc[df_index,f"{tag_type}_{tag_name}"] = df_tags_series.str.contains(str(tag_id)).astype(int)
#       8     df_true_false.loc[f"{tag_type}_{tag_name}"] = df["tags"].str.contains(str(tag_id))
#
# TypeError: Series.__init__() got an unexpected keyword argument 'sep'

# %%
df.head()
# Out:
#    index_tasty   id_                        name                      slug
# 0            0   868     Homemade Cinnamon Rolls   homemade-cinnamon-rolls  \
# 1            1  6124              Whipped Coffee            whipped-coffee
# 2            2  3094             Fluffy Pancakes   fluffy-perfect-pancakes
# 3            3  4693  How to Make Cinnamon Rolls  tasty-101-cinnamon-rolls
# 4            4  1655     Healthy Banana Pancakes   healthy-banana-pancakes
#
#                                            video_url
# 0  https://vid.tasty.co/output/25812/mp4_640x640/...  \
# 1  https://vid.tasty.co/output/163616/landscape_4...
# 2  https://vid.tasty.co/output/65088/landscape_48...
# 3  https://vid.tasty.co/output/121022/landscape_4...
# 4  https://vid.tasty.co/output/27116/mp4_640x640/...
#
#                                        thumbnail_url
# 0  https://img.buzzfeed.com/video-api-prod/assets...  \
# 1  https://img.buzzfeed.com/video-api-prod/assets...
# ...
